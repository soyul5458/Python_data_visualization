# %% [markdown]
# <a href="https://colab.research.google.com/github/soyul5458/Python_data_visualization/blob/main/1_Unzip_and_Loading_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --------------------------------------
# * Author : Han soyul
# * Date : 2023.07.27
# * Contact : soyul5458@cau.ac.kr
# --------------------------------------

# %% [markdown]
# # 1. Uploading .zip file to Google Drive
# Access Google Drive and upload the data file to be used for analysis.

# %% [markdown]
# # 2. Drive Mounting
# > What is Drive Mounting? It refers to connecting with Google Drive.
# > `drive.mount('Enter the folder to connect')` : Entering the same code as the example will connect to the entire Google Drive.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# → Note that the image above is the author's Google Drive (Click the folder icon on the left bar to check the user's Google Drive folder).

# %% [markdown]
# * **How to Execute Code in Each Cell**: Place the cursor on the cell to be executed > Press Shift + Enter simultaneously.

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # 3. Unzip
# `%cd Full path of the compressed file`
# `!unzip -qq "Location where the compressed file is stored/file name.zip"`

# %% [markdown]
# TIP: How to Easily Write the Path of the Compressed File
#
# Click on the folder icon > Click on the location where the compressed file is stored > Right-click on the compressed file and select Copy Path → !unzip -qq "Paste the copied content"
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
# %cd /content/drive/MyDrive/Data Visualization in Python/
# !unzip -qq "/content/drive/MyDrive/Data Visualization in Python/CVD_cleaned.csv.zip"

# %% [markdown]
# → Note that the author stored the zip file in the 'Data Visualization in Python' folder.

# %% [markdown]
# # 4. Loading Data
# `df = pd.read_csv('file name.csv')`

# %%
import pandas as pd

# %%
df = pd.read_csv('CVD_cleaned.csv')

# %% [markdown]
# f a Unicode error occurs, you need to add the encoding option.
#
# For example, `df = pd.read_csv('file name.csv',encoding = 'cp949')` or `df = pd.read_csv('file name.csv',encoding = 'utf-8')`

# %%
# Data Verification
df.head()
